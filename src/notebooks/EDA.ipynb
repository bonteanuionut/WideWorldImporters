# %%
import pandas as pd

# %%
test_output = pd.read_excel(r"D:\WideWorldImporters\WideWorldImporters\tests\fixtures\invoiceReportNovember2015.xlsx")
actual_output = pd.read_excel(r"D:\WideWorldImporters\WideWorldImporters\outputs\report.xlsx")

# %%
test_output.rename({"is Finalized?": "isFinalized"}, axis=1, inplace=True)

# %%
len(test_output)
# Out:
# 203

# %%
test_output.columns
# Out:
# Index(['SupplierID', 'SupplierName', 'SupplierInvoiceNumber',
#        'TransactionDate', 'AmountExcludingTax', 'isFinalized',
#        'PurchaseOrderID', 'OrderDate', 'PurchaseOrderLineID', 'StockItemID',
#        'Description', 'ReceivedOuters', 'ExpectedUnitPricePerOuter'],
#       dtype='str')

# %%
actual_output.columns == test_output.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
test_output.dtypes.sort_index() == actual_output.dtypes.sort_index()
# Out:
# AmountExcludingTax           True
# Description                  True
# ExpectedUnitPricePerOuter    True
# OrderDate                    True
# PurchaseOrderID              True
# PurchaseOrderLineID          True
# ReceivedOuters               True
# StockItemID                  True
# SupplierID                   True
# SupplierInvoiceNumber        True
# SupplierName                 True
# TransactionDate              True
# isFinalized                  True
# dtype: bool

# %%
test_output.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SupplierID                 203 non-null    int64
#  1   SupplierName               203 non-null    str
#  2   SupplierInvoiceNumber      203 non-null    int64
#  3   TransactionDate            203 non-null    datetime64[us]
#  4   AmountExcludingTax         203 non-null    float64
#  5   isFinalized                203 non-null    str
#  6   PurchaseOrderID            203 non-null    int64
#  7   OrderDate                  203 non-null    datetime64[us]
#  8   PurchaseOrderLineID        203 non-null    int64
#  9   StockItemID                203 non-null    int64
#  10  Description                203 non-null    str
#  11  ReceivedOuters             203 non-null    int64
#  12  ExpectedUnitPricePerOuter  203 non-null    float64
# ...

# %%
actual_output.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SupplierID                 203 non-null    int64
#  1   SupplierName               203 non-null    str
#  2   SupplierInvoiceNumber      203 non-null    int64
#  3   TransactionDate            203 non-null    datetime64[us]
#  4   AmountExcludingTax         203 non-null    float64
#  5   isFinalized                203 non-null    str
#  6   PurchaseOrderID            203 non-null    int64
#  7   OrderDate                  203 non-null    datetime64[us]
#  8   PurchaseOrderLineID        203 non-null    int64
#  9   StockItemID                203 non-null    int64
#  10  Description                203 non-null    str
#  11  ReceivedOuters             203 non-null    int64
#  12  ExpectedUnitPricePerOuter  203 non-null    float64
# ...

# %%
keys = list(filter(lambda x: "id" in x.lower() or x.lower() == "supplierinvoicenumber", test_output.columns))

# %%
keys
# Out:
# ['SupplierID',
#  'SupplierInvoiceNumber',
#  'PurchaseOrderID',
#  'PurchaseOrderLineID',
#  'StockItemID']

# %%
test_output.columns
# Out:
# Index(['SupplierID', 'SupplierName', 'SupplierInvoiceNumber',
#        'TransactionDate', 'AmountExcludingTax', 'isFinalized',
#        'PurchaseOrderID', 'OrderDate', 'PurchaseOrderLineID', 'StockItemID',
#        'Description', 'ReceivedOuters', 'ExpectedUnitPricePerOuter'],
#       dtype='str')

# %%
test_output["isFinalized"]
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4      YES
#       ...
# 198    YES
# 199    YES
# 200    YES
# 201    YES
# 202    YES
# Name: isFinalized, Length: 203, dtype: str

# %%
actual_output["isFinalized"]
# Out:
# 0      YES
# 1      YES
# 2      YES
# 3      YES
# 4      YES
#       ...
# 198    YES
# 199    YES
# 200    YES
# 201    YES
# 202    YES
# Name: isFinalized, Length: 203, dtype: str

# %%
s1 = test_output["isFinalized"] == actual_output["isFinalized"]
s1[s1 == False]
# Out:
# Series([], Name: isFinalized, dtype: bool)

# %%
full_output = test_output.merge(
    actual_output,
    left_on = keys,
    right_on = keys,
    how = "outer",
    suffixes = ["_test", "_output"],
    indicator=True
)

# %%
full_output.to_csv("test.csv")

# %%
full_output.count()
# Out:
# SupplierID                          203
# SupplierName_test                   203
# SupplierInvoiceNumber               203
# TransactionDate_test                203
# AmountExcludingTax_test             203
# isFinalized_test                    203
# PurchaseOrderID                     203
# OrderDate_test                      203
# PurchaseOrderLineID                 203
# StockItemID                         203
# Description_test                    203
# ReceivedOuters_test                 203
# ExpectedUnitPricePerOuter_test      203
# SupplierName_output                 203
# TransactionDate_output              203
# AmountExcludingTax_output           203
# isFinalized_output                  203
# OrderDate_output                    203
# Description_output                  203
# ReceivedOuters_output               203
# ExpectedUnitPricePerOuter_output    203
# _merge                              203
# dtype: int64

# %%
full_output[list(map(lambda x: x + "_test", keys)) + list(map(lambda x: x + "_output", keys))]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 full_output[list(map(lambda x: x + "_test", keys)) + list(map(lambda x: x + "_output", keys))]
#
# File d:\WideWorldImporters\WideWorldImporters\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File d:\WideWorldImporters\WideWorldImporters\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
# ...
